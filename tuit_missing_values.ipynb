# %%
import pandas as pd

# %%
data_frame=pd.read_csv("C:/Users/91749/Downloads/german_credit_risk.csv")

# %%
data_frame.isnull().sum()
# Out:
# Unnamed: 0            0
# Age                   0
# Sex                   0
# Job                   0
# Housing               0
# Saving accounts     183
# Checking account    394
# Credit amount         0
# Duration              0
# Purpose               0
# Risk                  0
# dtype: int64

# %%
data_frame.head(5)
# Out:
#    Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 0           0   67    male    2     own             NaN           little
# 1           1   22  female    2     own          little         moderate
# 2           2   49    male    1     own          little              NaN
# 3           3   45    male    2    free          little           little
# 4           4   53    male    2    free          little           little
#
#    Credit amount  Duration              Purpose  Risk
# 0           1169         6             radio/TV  good
# 1           5951        48             radio/TV   bad
# 2           2096        12            education  good
# 3           7882        42  furniture/equipment  good
# 4           4870        24                  car   bad

# %%
data_frame[["Saving accounts", "Checking account"]].fillna(
    data_frame[["Saving accounts", "Checking account"]].mode().iloc[0]).isnull().sum()
# Out:
# Saving accounts     0
# Checking account    0
# dtype: int64

# %%
data_frame[data_frame["Housing"] != "free"]
data_frame[data_frame["Risk"]!="good"]
data_frame[data_frame["Sex"]!="female"]
# Out:
#      Unnamed: 0  Age   Sex  Job Housing Saving accounts Checking account  \
# 0             0   67  male    2     own             NaN           little
# 2             2   49  male    1     own          little              NaN
# 3             3   45  male    2    free          little           little
# 4             4   53  male    2    free          little           little
# 5             5   35  male    1    free             NaN              NaN
# ..          ...  ...   ...  ...     ...             ...              ...
# 994         994   50  male    2     own             NaN              NaN
# 996         996   40  male    3     own          little           little
# 997         997   38  male    2     own          little              NaN
# 998         998   23  male    2    free          little           little
# 999         999   27  male    2     own        moderate         moderate
#
#      Credit amount  Duration              Purpose  Risk
# ...

# %%
data_frame.isnull().sum()
# Out:
# Unnamed: 0            0
# Age                   0
# Sex                   0
# Job                   0
# Housing               0
# Saving accounts     149
# Checking account    301
# Credit amount         0
# Duration              0
# Purpose               0
# Risk                  0
# dtype: int64

# %%
data_frame.dropna(subset=["Sex"]).isnull().sum()
# Out:
# Unnamed: 0            0
# Age                   0
# Sex                   0
# Job                   0
# Housing               0
# Saving accounts     149
# Checking account    301
# Credit amount         0
# Duration              0
# Purpose               0
# Risk                  0
# dtype: int64

# %%
data_frame.dropna(subset=["Saving accounts"]).isnull().sum()
# Out:
# Unnamed: 0            0
# Age                   0
# Sex                   0
# Job                   0
# Housing               0
# Saving accounts       0
# Checking account    220
# Credit amount         0
# Duration              0
# Purpose               0
# Risk                  0
# dtype: int64

# %%
data_frame["Credit amount"].where(data_frame["Credit amount"]>=600).sort_values().isnull().sum()
# Out:
# np.int64(15)

# %%
data_frame.dtypes
# Out:
# Unnamed: 0           int64
# Age                  int64
# Sex                 object
# Job                  int64
# Housing             object
# Saving accounts     object
# Checking account    object
# Credit amount        int64
# Duration             int64
# Purpose             object
# Risk                object
# dtype: object

# %%
data_frame["Age"].astype("int").head(9)
# Out:
# 0    67
# 1    22
# 2    49
# 3    45
# 4    53
# 5    35
# 6    53
# 7    35
# 8    61
# Name: Age, dtype: int64

# %%
data_frame.dtypes
# Out:
# Unnamed: 0           int64
# Age                  int64
# Sex                 object
# Job                  int64
# Housing             object
# Saving accounts     object
# Checking account    object
# Credit amount        int64
# Duration             int64
# Purpose             object
# Risk                object
# dtype: object

# %%
data_frame.nunique()
# Out:
# Unnamed: 0          809
# Age                  53
# Sex                   2
# Job                   4
# Housing               3
# Saving accounts       4
# Checking account      3
# Credit amount       757
# Duration             32
# Purpose               8
# Risk                  2
# dtype: int64

# %%
data_frame["Purpose"].value_counts(normalize=True) *100
# Out:
# Purpose
# car                    35.352287
# radio/TV               26.946848
# furniture/equipment    16.687268
# business               10.506799
# education               5.686032
# repairs                 2.472188
# vacation/others         1.359703
# domestic appliances     0.988875
# Name: proportion, dtype: float64

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 809 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        809 non-null    int64
#  1   Age               809 non-null    int64
#  2   Sex               809 non-null    object
#  3   Job               809 non-null    int64
#  4   Housing           809 non-null    object
#  5   Saving accounts   660 non-null    object
#  6   Checking account  508 non-null    object
#  7   Credit amount     809 non-null    int64
#  8   Duration          809 non-null    int64
#  9   Purpose           809 non-null    object
#  10  Risk              809 non-null    object
# dtypes: int64(5), object(6)
# memory usage: 75.8+ KB

# %%
#The columns which have data type as object will consume more storage therefore 
#to avoid that we convert the data type to category
data_frame["Housing"]=data_frame["Housing"].astype("category")

# %%
data_frame.dtypes
# Out:
# Unnamed: 0             int64
# Age                    int64
# Sex                   object
# Job                    int64
# Housing             category
# Saving accounts       object
# Checking account      object
# Credit amount          int64
# Duration               int64
# Purpose               object
# Risk                  object
# dtype: object

# %%
data_frame.sort_values(by="Age",ascending=True).head()
# Out:
#      Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 633         633   19  female    2    rent          little              NaN
# 428         428   20    male    2     own          little              NaN
# 495         495   20    male    2     own             NaN           little
# 905         905   20    male    3    rent          little           little
# 585         585   20  female    2    rent          little           little
#
#      Credit amount  Duration              Purpose  Risk
# 633           1980         9  furniture/equipment   bad
# 428           1313         9  furniture/equipment  good
# 495           2996        24  furniture/equipment   bad
# 905           1107        12             radio/TV  good
# 585           2039        18  furniture/equipment   bad

# %%
data_frame.sort_values(by="Purpose",ascending=True).tail(6)
# Out:
#      Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 818         818   43    male    3     own          little           little
# 72           72   51    male    3    free          little           little
# 442         442   29    male    2     own          little         moderate
# 431         431   29    male    3     own          little         moderate
# 915         915   32  female    3     own          little         moderate
# 310         310   40    male    0    free             NaN         moderate
#
#      Credit amount  Duration          Purpose  Risk
# 818          15857        36  vacation/others  good
# 72            1164         8  vacation/others  good
# 442           2629        20  vacation/others  good
# 431          11328        24  vacation/others   bad
# 915          18424        48  vacation/others   bad
# 310           5381        48  vacation/others  good

# %%
data_frame.sort_values(by=["Age","Duration"],ascending=[True,False]).head(7)
# Out:
#      Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 633         633   19  female    2    rent          little              NaN
# 93           93   20    male    2    rent             NaN             rich
# 495         495   20    male    2     own             NaN           little
# 593         593   20  female    1    rent          little         moderate
# 585         585   20  female    2    rent          little           little
# 155         155   20  female    2    rent          little           little
# 188         188   20    male    2     own        moderate           little
#
#      Credit amount  Duration              Purpose  Risk
# 633           1980         9  furniture/equipment   bad
# 93            3617        24  furniture/equipment  good
# 495           2996        24  furniture/equipment   bad
# 593           2718        24                  car   bad
# 585           2039        18  furniture/equipment   bad
# ...

# %%
data_frame.sort_values(by=["Sex","Housing"], ascending=[True, False]).tail()
# Out:
#      Unnamed: 0  Age   Sex  Job Housing Saving accounts Checking account  \
# 938         938   42  male    2    free          little         moderate
# 946         946   30  male    2    free      quite rich           little
# 959         959   30  male    2    free        moderate         moderate
# 988         988   29  male    3    free          little           little
# 998         998   23  male    2    free          little           little
#
#      Credit amount  Duration              Purpose  Risk
# 938           6288        60            education   bad
# 946           3349        24  furniture/equipment   bad
# 959           3069        24  furniture/equipment  good
# 988           6579        24                  car  good
# 998           1845        45             radio/TV   bad

# %%
pd.read_csv("C:/Users/91749/Downloads/german_credit_risk.csv", index_col=["Age"]).sort_index(ascending=False).head(4)
# Out:
#      Unnamed: 0     Sex  Job Housing Saving accounts Checking account  \
# Age
# 75          536  female    3     own             NaN           little
# 75          330    male    3    free          little           little
# 74          430    male    1     own          little              NaN
# 74          606    male    3     own          little              NaN
#
#      Credit amount  Duration   Purpose  Risk
# Age
# 75            1374         6       car  good
# 75            6615        24       car  good
# 74            3448         5  business  good
# 74            4526        24  business  good

# %%
data_frame["Credit rank"]=data_frame["Credit amount"].rank(ascending=False).astype(int)

# %%
data_frame.iloc[0:5,[2,4,11]].sort_values(by="Credit rank",ascending=False)
# Out:
#       Sex Housing  Credit rank
# 0    male     own          691
# 2    male     own          461
# 4    male    free          170
# 1  female     own          140
# 3    male    free           66

# %%
data_frame["Credit rank"].sort_values().head(3)
# Out:
# 915    1
# 95     2
# 818    3
# Name: Credit rank, dtype: int64

# %%
data_frame.sort_values("Credit amount",ascending=False).head(10)
# Out:
#      Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 915         915   32  female    3     own          little         moderate
# 95           95   58    male    2    rent          little         moderate
# 818         818   43    male    3     own          little           little
# 887         887   23    male    2     own          little         moderate
# 637         637   21    male    2     own          little              NaN
# 917         917   68    male    3     own          little           little
# 374         374   60  female    3    free        moderate         moderate
# 236         236   23    male    0     own             NaN         moderate
# 63           63   25    male    2     own          little         moderate
# 378         378   57    male    3    free          little         moderate
#
#      Credit amount  Duration          Purpose  Risk  Credit rank
# 915          18424        48  vacation/others   bad            1
# ...
