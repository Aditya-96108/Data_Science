# %%
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
foods= pd.read_csv("C:/Users/91749/Downloads/german_credit_risk.csv",usecols=["Housing"],index_col=[]).squeeze("columns")
max(foods)
min(foods)
sorted(foods)
foods
0 in foods
2 in foods.index
"free" in foods.values
"nonsense" in foods.values
# Out:
# False

# %%
foods.sort_values()
# Out:
# 852    free
# 602    free
# 360    free
# 607    free
# 609    free
#        ...
# 859    rent
# 124    rent
# 122    rent
# 570    rent
# 237    rent
# Name: Housing, Length: 1000, dtype: object

# %%
foods.head()
foods.head(n=10)
foods.head(1)
foods.tail(n=19)
# Out:
# 981    rent
# 982     own
# 983     own
# 984     own
# 985    rent
# 986     own
# 987     own
# 988    free
# 989     own
# 990     own
# 991     own
# 992    rent
# 993     own
# 994     own
# 995     own
# 996     own
# 997     own
# 998    free
# 999     own
# Name: Housing, dtype: object

# %%
len(foods)
type(foods)
list(foods)
# Out:
# ['own',
#  'own',
#  'own',
#  'free',
#  'free',
#  'free',
#  'own',
#  'rent',
#  'own',
#  'own',
#  'rent',
#  'rent',
#  'own',
#  'own',
#  'rent',
#  'own',
#  'own',
#  'own',
#  'free',
#  'own',
#  'own',
#  'rent',
#  'rent',
#  'own',
#  'own',
#  'own',
#  'own',
#  'rent',
#  'own',
#  'own',
#  'own',
#  'own',
#  'own',
#  'rent',
#  'own',
#  'own',
#  'free',
#  'own',
#  'own',
#  'own',
#  'own',
#  'own',
#  'own',
#  'rent',
#  'free',
#  'own',
#  'own',
#  'rent',
#  'own',
#  'own',
#  'own',
#  'own',
#  'own',
#  'own',
#  'free',
#  'own',
#  'own',
#  'own',
#  'own',
#  'rent',
#  'own',
#  'own',
#  'free',
#  'own',
#  'own',
#  'own',
#  'own',
#  'own',
#  'free',
#  'own',
#  'own',
#  'rent',
#  'free',
#  'own',
#  'own',
#  'free',
#  'own',
#  'own',
#  'own',
#  'own',
#  'own',
#  'own',
#  'rent',
#  'own',
#  'own',
#  'own',
#  'own',
#  'free',
#  'own',
#  'own',
#  'own',
#  'own',
#  'own',
#  'rent',
#  'own',
#  'rent',
#  'own',
# ...

# %%
sorted(foods)
dict(foods)
max(foods)
foods.sort_values(ascending=False) #This sort the values and changes the index accordingly 
sorted(foods) #sorts the values return a list
# Out:
# ['free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
#  'free',
# ...

# %%
foods= pd.read_csv("C:/Users/91749/Downloads/german_credit_risk.csv")
foods
foods["Credit amount"].max()
# Out:
# np.int64(18424)

# %%
data= pd.read_csv("C:/Users/91749/Downloads/german_credit_risk.csv",index_col=["Age"])
data.sort_index()
data[["Purpose","Housing"]].iloc[1:2].sort_index(ascending=False)
# Out:
#       Purpose Housing
# Age
# 22   radio/TV     own

# %%
unique_values = data['Saving accounts'].unique()
data["Credit amount"].loc[19]
# Out:
# Age
# 19     983
# 19    1980
# Name: Credit amount, dtype: int64

# %%
#Important Note loc is for labels and iloc is for index positions
data.loc[[19,23]]
# Out:
#      Unnamed: 0     Sex  Job Housing Saving accounts Checking account  \
# Age
# 19          391  female    1    rent            rich         moderate
# 19          633  female    2    rent          little              NaN
# 23           47  female    0    rent      quite rich           little
# 23           58  female    3     own          little             rich
# 23           59  female    1    rent          little           little
# 23          111  female    2    rent          little             rich
# 23          118  female    2     own      quite rich           little
# 23          144  female    2     own          little              NaN
# 23          217    male    2     own          little             rich
# 23          221  female    2    rent             NaN           little
# 23          236    male    0     own             NaN         moderate
# 23          258  female    2     own        moderate              NaN
# ...

# %%
#get() is also very similar to loc attribute the only difference is that if the index does not exist 
#loc gives error and get() returns nothing
data.loc[17]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\91749\Desktop\Data_Science_Repository\venv\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:191, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:234, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# File index.pyx:242, in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# File index.pyx:134, in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: 17
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 3
# ...

# %%
data.get(17,'not found 😒😒')
# Out:
# 'not found 😒😒'

# %%
data.iloc[[1,2,3]]
# Out:
#      Unnamed: 0     Sex  Job Housing Saving accounts Checking account  \
# Age
# 22            1  female    2     own          little         moderate
# 49            2    male    1     own          little              NaN
# 45            3    male    2    free          little           little
#
#      Credit amount  Duration              Purpose
# Age
# 22            5951        48             radio/TV
# 49            2096        12            education
# 45            7882        42  furniture/equipment

# %%
data_squeezed = pd.read_csv("C:/Users/91749/Downloads/german_credit_risk.csv",index_col="Age").squeeze("columns")

# %%
data_squeezed
# Out:
#      Unnamed: 0     Sex  Job Housing Saving accounts Checking account  \
# Age
# 67            0    male    2     own             NaN           little
# 22            1  female    2     own          little         moderate
# 49            2    male    1     own          little              NaN
# 45            3    male    2    free          little           little
# 53            4    male    2    free          little           little
# ..          ...     ...  ...     ...             ...              ...
# 31          995  female    1     own          little              NaN
# 40          996    male    3     own          little           little
# 38          997    male    2     own          little              NaN
# 23          998    male    2    free          little           little
# 27          999    male    2     own        moderate         moderate
#
#      Credit amount  Duration              Purpose  Risk
# Age
# 67            1169         6             radio/TV  good
# ...

# %%
foods = pd.read_csv("C:/Users/91749/Downloads/german_credit_risk.csv", usecols=["Age"]).squeeze("columns")

# %%
foods.head()
# Out:
# 0    67
# 1    22
# 2    49
# 3    45
# 4    53
# Name: Age, dtype: int64

# %%
type(foods)
# Out:
# pandas.core.frame.DataFrame

# %%
foods = pd.read_csv("C:/Users/91749/Downloads/german_credit_risk.csv", usecols=["Age"]).squeeze("columns")

# %%
foods.loc[[21,23,24]]
# Out:
# 21    44
# 23    44
# 24    26
# Name: Age, dtype: int64

# %%
foods.iloc[[1,2,3]]=[44,45,46]

# %%
foods.head(9)
# Out:
# 0    67
# 1    44
# 2    45
# 3    46
# 4    53
# 5    35
# 6    53
# 7    35
# 8    61
# Name: Age, dtype: int64

# %%
foods.describe().unique()
# Out:
# array([1000.        ,   35.565     ,   11.36736522,   19.        ,
#          27.        ,   33.        ,   42.        ,   75.        ])

# %%
#Function	        What it does	       Example
#.mean()	        Average value	       fruit_prices.mean()
#.sum()	            Total of all values	   fruit_prices.sum()
#.max()	            Highest value	       fruit_prices.max()
#.min()	            Smallest value	       fruit_prices.min()
#.sort_values()	Sort by values	            fruit_prices.sort_values()
#.index, .values	Shows labels and values	fruit_prices.index
